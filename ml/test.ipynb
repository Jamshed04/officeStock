# %%
import pandas as pd
from tqdm import tqdm
import re
import nltk
from nltk.corpus import stopwords
from contextlib import redirect_stdout
import os
import config.settings as settings

# %%
root_path = settings.ROOT_DIR

goods_df = pd.read_excel(root_path / 'data/marked.xlsx', sheet_name='Data_new')
names_list = goods_df['name'].tolist()

nltk.download('stopwords', download_dir=root_path/'lib/nltk_data')
stop_words = set(stopwords.words('russian'))
for i, name in tqdm(enumerate(names_list), total=len(names_list)):
    name = names_list[i]
    text = name
    text = re.sub(r"«.*»", "", text)
    text = re.sub(r"([(][^)]+[)])|([\d]+\s?[в]\s?[\d+]|[№][\d]+)", "", text)
    text = re.sub(r"([\d]+[.,]?[\d]+[%])|([\d]+[%])|(\d+[+])", "", text)
    text = re.sub(r"\b\d+\s?(г|гр|гр\.|мл|л|шт|уп|пакет|%)\b", "", text, flags=re.IGNORECASE)
    text = re.sub(r"[ ]{2,}", " ", text)
    words = [w for w in text.lower().split() if w not in stop_words]
    text = " ".join(words)
    names_list[i] = text
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Admin\Documents\
# [nltk_data]     Study\Projects\7_semester\MDP\lib\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 100%|██████████| 7687/7687 [00:00<00:00, 85483.20it/s]

# %%
names_list
# Out:
# ['салатный микс модена',
#  'салат кейл',
#  'лонган',
#  'шпинат',
#  'салатный микс аликанте',
#  'салатный микс тоскана',
#  'проростки фасоли маш',
#  'груша нэши',
#  'морковь свежая соломка',
#  'мята',
#  'дыня канталупа',
#  'слива стенлей',
#  'лук ялтинский',
#  'салатный микс руккола',
#  'салат руккола',
#  'бананы поштучно',
#  'лимоны поштучно',
#  'микрозелень гороха',
#  'капуста белокочанная шинкованная',
#  'томаты розовые',
#  'перец ласточка',
#  'яблоки гала поштучно',
#  'перец халапеньо',
#  'шампиньоны свежие',
#  'кинза',
#  'лук зелёный',
#  'яблоки голден поштучно',
#  'яблоки гренни поштучно',
#  'набор зелени укроп',
#  'яблоки ред поштучно',
#  'груша хрустальная',
#  'груши лесная красавица поштучно',
#  'шпинат',
#  'салат горшочке',
#  'груши пакхам поштучно',
#  'груши конференция поштучно',
#  'укроп свежий',
#  'огурец гладкий среднеплодный поштучно',
#  'апельсины поштучно',
#  'мандарины',
#  'мандарины листочком',
#  'томаты розовые узбекистан',
#  'томаты сливовидные красные',
#  'дыня туркменка',
#  'редис',
#  'дыня торпеда',
#  'картофель батат',
#  'картофель весовой',
#  'картофель мытый',
#  'морковь мытая',
#  'помело красное',
#  'морковь импорт',
#  'морковь',
#  'свёкла поштучно',
#  'свёкла отварная',
#  'виноград черный',
#  'виноград киш-миш черный',
#  'виноград дамские пальчики',
#  'виноград белый хусайни',
#  'виноград кишмиш белый',
#  'лук репчатый белый',
#  'чеснок',
#  'чеснок',
#  'лук репчатый красный',
#  'лук репчатый желтый',
#  'лайм .',
#  'тыква очищенная',
#  'тыква бутылочка поштучно',
#  'питахайя белая',
#  'помело желтое',
#  'очищенный кокос питьевой',
#  'персики плоские',
#  'гранат поштучно',
#  'грейпфрут поштучно',
#  'томаты черри',
#  'салат айсберг',
#  'свёкла свежая соломка',
#  'виноград мускат',
#  'перец чили красный',
#  'персики свежие',
#  'капуста шинкованная морковью',
#  'огурцы колючие короткоплодные',
#  'томаты',
#  'яблоки свежий урожай',
#  'перец красный поштучно',
#  'грибы вешенка',
#  'томаты черри делтари',
#  'петрушка свежая',
#  'яблоко симиренко поштучно',
#  'стебель сельдерея поштучно',
#  'авокадо хасс',
#  'авокадо',
#  'томат коктейльный ветке',
#  'томаты сливовидные желтые',
#  'арбуз',
#  'нектарин',
#  'яблоки голден импорт',
#  'перец красный поштучно',
#  'перец чили поштучно',
#  'редька дайкон поштучно',
#  'капуста белокочанная поштучно',
#  'слива президент',
#  'слива медовая',
#  'манго желтое',
#  'виноград тайфи',
#  'молоко',
#  'йогурт crispy карамелью смесью семян подсолнечника орехов карамели',
#  'сырок творожный манго семенами чиа',
#  'крем растительных маслах вкусом базилика',
#  'напиток сывороточный яблоко',
#  'кефир',
#  'молоко',
#  'крем растительных маслах 4 масла',
#  'напиток сывороточный лимонад',
#  'топпинг сливочный банан',
#  'масло сливочное крестьянское',
#  'коктейль молочный «три коровы',
#  'йогурт греческий',
#  'молоко цельное/отборное 3',
#  'сметана',
#  'топпинг сладкий кокос',
#  'коктейль молочный «три коровы',
#  'яйцо перепелиное',
#  'масло сливочное традиционное',
#  'йогурт бабл гам',
#  'яйцо куриное с0',
#  'кефир',
#  'молоко топленое',
#  'яйцо куриное с1',
#  'маргарин универсальный',
#  'сметана',
#  'масло сливочное крестьянское',
#  'йогурт ягодное конфети малина-клюква',
#  'яйцо куриное с2',
#  'молоко питьевое',
#  'йогурт питьевой яблоко-груша',
#  'сыр плавленый колбасный копченый',
#  'молоко ультрапастеризованное',
#  'молоко ультрапастеризованное',
#  'коктейль молочный банан',
#  'сырок творожный глазированный печеньем сгущенным молоком',
#  'йогурт питьевой манго',
#  'коктейль молочный клубника',
#  'сырок творожный глазированный печеньем клубникой',
#  'йогурт классический',
#  'молоко сгущенное цельное сахаром',
#  'сырок творожный молочной шоколадной глазури клубникой печенье',
#  'биойогурт грушей',
#  'молоко цельное сгущенное сахаром',
#  'сырок творожный глазированный соленая карамель',
#  'йогурт very berry вишней 2',
#  'молоко сгущенное вареное сахаром',
#  'йогурт very berry зеленое яблоко 2',
#  'молоко козье отборное slim leaf',
#  'биойогурт земляника',
#  'молоко цельное сгущенное сахаром',
#  'суфле молочное варёной сгущенкой молочном шоколаде',
#  'кефир',
#  'суфле молочное вкусом ванили молочном шоколаде',
#  'сырок творожный collagen',
#  'сырок творожный protein',
#  'молоко обогащенное',
#  'сыр косичка копченая',
#  'масло сливочное крестьянское',
#  'молоко цельное сгущенное сахаром',
#  'молочный коктейль ванильный пломбир',
#  'йогуртный продукт легкий ананас дыня/ лесные ягоды',
#  'молочный напиток соленая карамель',
#  'йогуртный продукт легкий персик – маракуйя/ вишня',
#  'сыр творожный прованскими травами',
#  'сырок творожный вафельном рожке сгущенка',
#  'сыр плавленый грибами супа',
#  'сырок творожный вафельном рожке малина',
#  'сыр плавленый дружба',
#  'сырок творожный глазированный ваниль',
#  'коктейль молочный пломбир',
#  'кефир',
#  'сырок творожный глазированный клубника',
#  'коктейль молочный клубничный',
#  'сметана',
#  'сырок творожный глазированный какао',
#  'пирожное бисквитное молочной начинкой',
#  'сыр плавленый сливочный',
#  'сырок творожный глазированный персик-маракуйя',
#  'йогуртный продукт клубникой',
#  'йогуртный продукт персиком',
#  'йогурт безлактозный lactose free абрикос-персик',
#  'кефир',
#  'йогурт безлактозный lactose free клубника-маракуйя',
#  'сыр голубой благородной плесенью',
#  'йогурт безлактозный lactose free малина-инжир',
#  'сыр плавленый ветчиной',
#  'сыр камамбер плесенью',
#  'йогурт laplandia десерт вкусом фисташки',
#  'сыр плавленый сливочный',
#  'сыр бри плесенью',
#  'йогурт laplandia вкусом черничного маффина',
#  'ряженка',
#  'сыр творожный зелень',
#  'йогурт laplandia вкусом крем-брюле',
#  'сметана',
#  'йогурт гранола изюм',
#  'ряженка',
#  'сыр плавленый сливочный',
#  'сырок творожный глазированный клубника',
#  'молоко',
#  'сметана',
#  'йогурт питьевой ягоды-мороженое',
#  'сырок творожный глазированный ванильный',
#  'ряженка',
#  'йогурт питьевой клубника-земляника',
#  'сыр творожный сливочный',
#  'сыр брынза по-итальянски козьего молока',
#  'трубочки молока ягодный микс',
#  'сыр мягкий монарх',
#  'коктейль молочный клубника',
#  'сыр моцарелла бутербродов',
#  'сыр моцарелла фиор ди латте воде',
#  'сырок творожный ванилью',
#  'сыр мягкий рикотта',
#  'сырок творожный изюмом',
#  'ряженка',
#  'сыр моцарелла чильеджина воде',
#  'сырок творожный',
#  'сырок творожный кокосом',
#  'сыр плавленый бургера',
#  'снежок',
#  'сырок творожный сгущенкой',
#  'сок молоком персик-маракуйя',
#  'сыр молодрой скаморца',
#  'снежок',
#  'сыр сулугуни',
#  'десерт творожный flavorite груша',
#  'молоко',
#  'сыр рикотта',
#  'десерт творожный flavorite вишня шоколад',
#  'десерт творожный flavorite соленая карамель',
#  'айран вялеными томатами',
#  'молоко',
#  'йогурт питьевой черникой',
#  'айран пряными травами',
#  'йогурт питьевой вишней',
#  'айран традиционный',
#  'йогурт питьевой клубникой',
#  'йогурт питьевой персиком',
#  'сметана',
#  'кисломолочный напиток айран газированный',
#  'молоко безлактозное',
#  'йогурт питьевой апельсин-ананас',
#  'сыр плавленый маасдам',
#  'сыр мягкий камамбер белой плесенью + мёд',
#  'кисломолочный напиток тан газированный',
#  'йогурт питьевой арбуз-мята',
#  'сыр плавленый беконом',
#  'молоко',
#  'йогурт питьевой клубника маракуйя',
#  'напиток кисломолочный солью',
#  'сыр плавленый супа сливочный',
#  'напиток кисломолочный вкусом соленого огурца укропом',
#  'пудинг карамельный',
#  'сыр плавленый дружба',
#  'пудинг шоколадный',
#  'творог обезжиренный',
#  'сыр анари легкий',
#  'пудинг ванильный',
#  'биолакт детский',
#  'творог',
#  'йогуртный продукт',
#  'сыр плавленый беконом',
#  'биолакт детский',
#  'творог',
#  'сыр плавленый грибами',
#  'сыр сербская брынза',
#  'сыр плавленый hunter parmesan',
#  'йогурт питьевой добавления сахара',
#  'творог',
#  'сыр камамбер брусничным соусом',
#  'сыр жарки',
#  'сыр мягкий',
#  'сыр рассольный',
#  'сыр буратта',
#  'кисломолочный напиток земляника',
#  'желе фруктовое персиком',
#  'желе фруктовое вишней',
#  'трубочки молока шоколад',
#  'сыр голландский',
#  'сыр российский',
#  'сыр сметанковый',
#  'сыр тильзитер',
#  'сыр полутвердый тертый',
#  'сыр тильзитер',
#  'сыр козьего молока каприно романо',
#  'йогурт питьевой абрикосовый',
#  'сыр эдам',
#  'йогурт питьевой лесные ягоды',
#  'йогурт питьевой натуральный',
#  'йогурт греческий черникой',
#  'сыр швейцарский',
#  'йогурт греческий клубникой',
#  'сыр гауда',
#  'сыр маасдам',
#  'творог',
#  'сливки питьевые безлактозные',
#  'творожок ванилином',
#  'творожок кусочками жимолости',
#  'сливки',
#  'сыр императорский',
#  'творожок кусочками кокоса-ананаса',
#  'сыр балтасинский мраморный',
#  'творожок печеное яблоко-корица',
#  'сливки порционные',
#  'йогурт классический сахара',
#  'сыр голландский',
#  'йогурт клубника – малина',
#  'сливки питьевые',
#  'йогурт черника – ежевика',
#  'сыр matured havarti',
#  'йогурт персик – манго',
#  'сливки',
#  'сыр пармезан премиум',
#  'сливки «три коровы',
#  'йогурт вишня – черешня',
#  'биойогурт питьевой персик-маракуйя',
#  'сыр эдам',
#  'творог обезжиренный',
#  'биойогурт питьевой вишня',
#  'сливки стерилизованные',
#  'биойогурт питьевой клубника',
#  'биойогурт питьевой черника',
#  'биойогурт вишня-черешня',
#  'биойогурт малина',
#  'сыр легкий',
#  'биойогурт персик-абрикос',
#  'сыр romber premium козьим молоком',
#  'творог',
#  'сыр твердый чеддер',
#  'творог',
#  'сыр твердый palermo',
#  'сыр король сыров ароматом топленного молока',
#  'сыр чеддер',
#  'сыр охотничий',
#  'творожное зерно сливках',
#  'творожное зерно сливках клубника',
#  'творожное зерно сливках черника',
#  'сыр тильзитский',
#  'сыр белорусское золото',
#  'йогурт манго семена чиа',
#  'сыр легкий',
#  'йогурт натуральный',
#  'йогурт crispy фисташками смесью семян подсолнечника',
#  'сыр пармезан',
#  'йогурт вишня-черешня',
#  'сыр грюйер',
#  'йогурт персик-маракуйя',
#  'сыр young добавлением сушеных грибов',
#  'йогурт гранат-малина',
#  'сыр молодой пармезан',
#  'йогурт ананас',
#  'масса творожная изюмом',
#  'сыр спагетти',
#  'масса творожная курагой',
#  'творожная масса ванильная',
#  'творожная масса какао',
#  'йогурт питьевой натуральный',
#  'йогурт питьевой киви-виноград',
#  'творог',
#  'сыр олдермани',
#  'сыр гауда',
#  'сыр бутербродный',
#  'сыр тильзитер',
#  'творог клубника-банан',
#  'творог черникой',
#  'творог манго',
#  'йогурт ароматом абрикоса',
#  'йогурт ароматом клубники',
#  'кисломолочный напиток малиновый пломбир',
#  'кисломолочный напиток клубничное мороженое',
#  'йогурт питьевой малина',
#  'йогурт питьевой клубника-банан',
#  'творог взбитый вишня-черешня',
#  'творог взбитый клубника-земляника',
#  'йогурт легкий клубничный',
#  'желе вкусом земляники',
#  'желе вкусом яблока',
#  'соус шоколад',
#  'сырок творожный',
#  'йогурт греческий',
#  'масло сливочное крестьянское',
#  'соус карамель морской солью',
#  'йогурт шоколадное настроение',
#  'йогурт питьевой клубника-банан',
#  'сметана',
#  'йогурт греческий обезжиренный',
#  'молоко ультрапастеризованное',
#  'сырок творожный',
#  'биойогурт абрикос-манго',
#  'сыр гауда',
#  'кефир',
#  'сыр гурманский нарезке',
#  'молоко детского питания',
#  'десерт творожный flavorite банан ореховый крем',
#  'сыр буррата',
#  'сыр страчателла',
#  'биолакт яблоко-груша',
#  'йогурт питьевой клубничный',
#  'сыр страчателла',
#  'пирожное бисквитное сливочным вкусом',
#  'йогурт двухслойный малина',
#  'йогурт двухслойный персик',
#  'сыр',
#  'творог',
#  'пирожное протеиновое',
#  'вафельный сэндвич ореховой начинкой',
#  'джем лесные ягоды',
#  'паста шоколадно-ореховая',
#  'пирожное бисквитное кремом молоком орехово-шоколадной начинкой',
#  'крекер французский мини',
#  'жевательная резинка биг бабол клубника',
#  'рахат-лукум фундуком',
#  'пастилки яблочные',
#  'паста ореховая какао',
#  'джем черничный',
#  'конфеты',
#  'крекер мини вкусом грибы сметаной',
#  'жевательная резинка биг бабол яблоко',
#  'пряник яблоко-корица',
#  'чак-чак медовый',
#  'пастилки сливовые',
#  'торт суфлейный птичка прохорова',
#  'жевательная резинка',
#  'конфеты',
#  'крекер мини картофельный зеленью',
#  'ореховая паста какао',
#  'конфеты нуга-кокос',
#  'трубочки вафельные double кокосом белом шоколаде',
#  'фруктовая лента манго',
#  'чизкейк клубничный',
#  'жевательная резинка вкусом эвкалипта ментола',
#  'барабублик карамельный',
#  'драже двухслойный шоколад цветной глазури',
#  'фруктовая лента яблоко',
#  'вафельный сэндвич какао молочной начинкой',
#  'шоколадный батончик мульти',
#  'меренговый рулет',
#  'жевательная резинка вкусом вишни ментола',
#  'карамель палочке',
#  'печенье протеиновое лесной орех',
#  'жевательная резинка white',
#  'драже цитрусовый микс',
#  'конфеты марципановая картошка манго',
#  'мини-пряники вареной сгущенкой',
#  'маршмеллоу duo',
#  'вафли какао',
#  'мини-пряники малиновой начинкой',
#  'choco pie какао',
#  'мармелад жевательный',
#  'маршмеллоу trio',
#  'козинак арахисовый',
#  'вафли арахисовые',
#  'choco pie клубничный',
#  'карельский пирог брусникой яблоком',
#  'маршмеллоу jam',
#  'вафли какао',
#  'мини-пышечки заварные белой глазури',
#  'мармелад кота',
#  'маршмеллоу solo',
#  'конфеты трюфельной начинкой',
#  'шоколад молочный кокос',
#  'освежающие пастилки вкусом манго',
#  'мёд цветочный',
#  'халва подсолнечная',
#  'торт вафельный шоколадный фундуком',
#  'печенье протеиновое шоколадное',
#  'ирис кокос',
#  'пряники шоколадные',
#  'халва арахисовая',
#  'печенье какао сливочным кремом',
#  'мармелад жевательный',
#  'шоколад молочный ягодный duo. яркая смородина',
#  'пряники вишневой начинкой',
#  'мёд гречишный',
#  'пастилки вкусом яблока корицы',
#  'козинак кунжутный',
#  'пастилки фрутилки груша',
#  'мармелад жевательный',
#  'шоколадный батончик экстра соленая карамель',
#  'пряники вареной сгущенкой',
#  'шоколадный батончик',
#  'печенье сдобное',
#  'пастилки фрутилки персик',
#  'мармелад жевательный «глаз',
#  'пирожное протеиновое брауни классическое',
#  'пряники мятные',
#  'вафля голландская карамельной начинкой',
#  'баггетсы мультизлаковые морской солью',
#  'маршмеллоу solo',
#  'австрийский штрудель маком',
#  'брауни',
#  'конфеты шоколадные galaxy sphere',
#  'молочный шоколад арахисом солёной карамелью',
#  'пряники классические',
#  'зефир чёрной смородиной',
#  'хлебные палочки семенами льна подсолнечника',
#  'профитроли шоколадной начинкой',
#  'мармелад hot wheels',
#  'молочный шоколад ореховой начинкой дробленым фундуком',
#  'вафли тонкие кокосовым кремом',
#  'пирожные корзиночки белковым кремом',
#  'маршмеллоу вкусом черники дыни',
#  'мини-пай голландский малиновой начинкой',
#  'брауни горячий шоколад',
#  'молочный шоколад карамельной начинкой солёной карамелью',
#  'жевательная резинка',
#  'тараллини классические',
#  'вафли тонкие кремом клубничным вкусом',
#  'клубника протертая сахаром',
#  'пахлава грецким орехом',
#  'пай голландский малиновой начинкой',
#  'мармелад кислый страйпс',
#  'шоколад молочный тропический кокос',
#  'тараллини чесноком',
#  'мини-круассаны сливочным кремом',
#  'вафли тонкие какао молочным кремом',
#  'манго протертое сахаром',
#  'мини-рулеты глазированные солёной карамелью',
#  'жевательная резинка',
#  'мини-круассаны шоколадным кремом',
#  'маршмеллоу trio',
#  'рулет бисквитный какао глазированный',
#  'печенье',
#  'конфеты шоколадно-ореховой начинкой',
#  'аскорбинка вкусом клубники',
#  'батончик марципановая буханка',
#  'жевательная резинка вкусом клубники',
#  'мини-круассан клубничным джемом',
#  'маршмеллоу duo',
#  'вафельная трубочка ореховой пастой какао',
#  'жевательная резинка вкусом арбуза',
#  'вафельные рулетики вкусом сгущённого молока',
#  'мини-пай голландский яблочной начинкой',
#  'карамель кофе',
#  'конфеты молочной начинкой',
#  'халва подсолнечная',
#  'рулет бисквитный шоколадный',
#  'зефир шоколаде манго',
#  'крендельки бретцель молочном шоколаде',
#  'мини-пай голландский яблочной начинкой',
#  'мармелад подарком леди баг',
#  'рулет бисквитный варёной сгущёнкой',
#  'торт strike',
#  'драже молочной шоколадной глазури',
#  'козинак подсолнечный',
#  'рулет бисквитный вишнёвый',
#  'конфеты шоколадные',
#  'батончик протеиновый marshmallow ароматом вишни молочном шоколаде',
#  'рулет бисквитный клубника сливками',
#  'ирис арахисом',
#  'мягкие вафли вишневым джемом',
#  'тараллини классические',
#  'choco pie',
#  'пирожное миндальное macaron лимон',
#  'жевательная резинка big babol клубника',
#  'батончик протеиновый marshmallow соленой карамелью молочном шоколаде',
#  'ирис шоколадным вкусом',
#  'пирожное миндальное macaron клубника',
#  'жевательная резинка xxl',
#  'choco pie банановый',
#  'торт nils',
#  'драже молочный шоколад цветной глазури',
#  'ирис сливочный',
#  'десерт redcap',
#  'choco pie клубничный',
#  'батончик protein миндаль арахис',
#  'десерт',
#  'сушки папина малышка',
#  'жевательная резинка pure fresh тутти фрутти xxl',
#  'батончик protein миндаль',
#  'десерт fun ban',
#  'конфеты манго шоколадной глазури',
#  'десерт морковный',
#  'choсo pie кокосовый',
#  'фруктовый батончик банан молочном шоколаде',
#  'бисквитное пирожное малиновой начинкой',
#  'соломка глазури кокосовой стружкой',
#  'пастилки маршмеллоу спелая клубника',
#  'шоколад молочный миндалем',
#  'варенье малина',
#  'пирожное macaron шоколад',
#  'печенье вкусом топлёного молока',
#  'бисквитное пирожное вареной сгущенкой',
#  'эклеры шоколадные',
#  'шоколадные конфеты',
#  'бисквитное пирожное банановой начинкой',
#  'эклеры сливочные',
#  'пирожное картошка',
#  'трубочки вафельные',
#  'мармелад жевательный глаз',
#  'батончик фисташкой',
#  'зефир ванильный',
#  'конфеты вафельные шоколадно-ореховой начинкой',
#  'печенье овсяное',
#  'мармелад жевательный колечки вкусом персика',
#  'батончик',
#  'бисквит малиновой начинкой',
#  'конфеты вафельные кремово-ореховой начинкой',
#  'печенье',
#  'батончик бананом арахисом',
#  'панкейк вареной сгущенкой',
#  'зефир малиной',
#  'чизкейк ванильный',
#  'батончик кешью клубникой',
#  'зефир ванильный глазированный',
#  'торт kremka',
#  'гематоген классический',
#  'шоколадные конфеты',
#  'печенье',
#  'драже молочный шоколад цветной глазури',
#  'конфеты шоколадные вкус романтического вечера',
#  'жевательная резинка ягодный микс',
#  'вафли лимон-лайм',
#  'мини-рулет клубничный',
#  'сухари сахаром сладкое чудо',
#  'шоколад молочной начинкой',
#  'вафли ореховые',
#  'печенье сахарное апельсиновым вкусом',
#  'мармелад жевательный лягушки',
#  'вафли варёной сгущёнкой',
#  'рулет бисквитный сыром маскарпоне',
#  'печенье десерт шоколадный вишней',
#  'мармелад жевательный мозг',
#  'жевательная резинка white bubblemint',
#  'трубочки вафельные вкусом сгущенки',
#  'мини-рулет бисквитный клубничный',
#  'печенье',
#  'карамель леденцовая палочке',
#  'шоколадный батончик white almonds',
#  'вафли сливочные',
#  'choco pie',
#  'шоколадный батончик white with strawberry crisps and popping candy',
#  'жевательная резинка white нежная мята',
#  'вафли халвой',
#  'печенье choco stix молочном шоколаде',
#  'торт сашер',
#  'вафли сливочные',
#  'хрустящие палочки глазури арахисом',
#  'печенье',
#  'жевательная резинка сладкая мята',
#  'вафли шоколадом',
#  'фаготтини яблочным джемом',
#  'шоколад double milk white chocolate',
#  'жевательная резинка клубника-банан',
#  'вафельный сэндвич шоколадной начинкой',
#  'воздушный рис сахаре',
#  'хрустящие палочки глазури воздушным рисом',
#  'печенье',
#  'батончик миндалем',
#  'вафли глазированные',
#  'батончик миндалем арахисом',
#  'конфеты',
#  'вафли голландские варёной сгущёнкой',
#  'конфеты вкусом йогурта черникой',
#  'вафли карамельной начинкой',
#  'ирис шоколадный',
#  'печенье шоколадным вкусом',
#  'пирожное тирамису',
#  'мармелад жевательный черепа кости',
#  'вафли голландские карамельной начинкой',
#  'печенье вкусом пломбира',
#  'карамель палочке кислый kiss',
#  'вафли мягкие вареной сгущенкой',
#  'печенье',
#  'вафли мягкие варёной сгущёнкой',
#  'сахарная вата',
#  'вафли мягкие вишнёвым джемом',
#  'белой глазури',
#  'пирожные заварным кремом',
#  'миндальный батончик protein',
#  'мармелад жевательный страйпсы',
#  'карамель b-pop вкусом тропических фруктов',
#  'батончик протеиновый молочный молочном шоколаде',
#  'батончик фруктовый протеином',
#  'конфеты вкусом вишни',
#  'шоколад белый c клубничными криспами',
#  'шоколад белый ананас взрывная карамель',
#  'жевательная резинка свежая мята',
#  'тарты по-французски заварным кремом',
#  'печенье-сэндвич шоколадно-ореховым вкусом',
#  'печенье-сендвич шоколадно-сливочным вкусом',
#  'вафельный батончик creamy dark',
#  'конфеты',
#  'печенье-сендвич клубничным кремом',
#  'карамель палочке',
#  'вафельный батончик creamy white',
#  'шоколад молочный extra milk hazelnut',
#  'мини-сушка сдобная',
#  'пирожное бисквитное delice',
#  'шоколад горький darkorange',
#  'жевательная резинка pure fresh виноград',
#  'печенье затяжное сливочным кремом',
#  'крекер-сэндвич арахисовой пастой морской солью',
#  'шоколадный батончик extra milk hazelnut',
#  'батончик фруктовый',
#  'конфеты вафельные creamy',
#  'шоколадный батончик extra milk',
#  'жевательная резинка xxl',
#  'австрийский штрудель яблоком корицей',
#  'жевательные конфеты шоколадным кремом',
#  'шоколадный батончик extra milk sea salted caramel',
#  'австрийский штрудель вишней',
#  'мармелад жевательный форме сороконожек',
#  'баранка',
#  'мини-сушка',
#  'конфеты frulli суфле банана шоколаде',
#  'конфеты frulli суфле манго шоколаде',
#  'печенье курабье',
#  'конфеты frulli суфле малины шоколаде',
#  'печенье ванильное кольцо',
#  'мармелад жевательный форме бабочек',
#  'соломка сладкая дочки',
#  'конфеты c молочной начинкой',
#  'мармелад жевательный perfect match',
#  'батончик вафельный choco молочном шоколаде',
#  'лимон имбирь перетёртые сахаром',
#  'торт любимая сказка',
#  'мармелад жевательный форме забавных змеек посыпке легкой кислинкой',
#  'мармелад жевательный форме забавных бутылочек',
#  'мармелад жевательный форме забавных змеек кислой посыпке',
#  'вафельный батончик шоколад-фундук',
#  'брусника протертая сахаром',
#  'мармелад жевательный форме озорных мишек',
#  'вафельный батончик крем-фундук',
#  'земляника протертая сахаром',
#  'вафли варёной сгущенкой',
#  'печенье сахарное',
#  'жевательный мармелад змейки',
#  'вафли шоколадом',
#  'конфеты молочной начинкой',
#  'шоколадный батончик малиновой начинкой',
#  'мармелад жевательный змейка',
#  'шоколад темный aerated',
#  'датские булочки сливками',
#  'вафли мягкие шоколадным кремом',
#  'жевательная резинка ароматом мяты сахара',
#  'мармелад жевательный форме машинок',
#  'печенье белой глазури',
#  'варенье абрикосовое',
#  'пирожное безе',
#  'жевательная резинка ледяная вишня',
#  'батончик кешью',
#  'торт вафельный орехом',
#  'конфеты освежающие клубника',
#  'батончик какао-мята',
#  'конфеты кедровым орехом клюквой шоколаде',
#  'печенье сдобное',
#  'трубочки вафельные ореховые',
#  'батончик-суфле клубнично-банановый',
#  'конфеты банан сушеный',
#  'печенье сдобное американское',
#  'горький шоколад no sugar added darkorange',
#  'жевательные конфеты ягодный микс',
#  'мармелад жевательный ананас-яблоко-клубника',
#  'печенье сдобное',
#  'горький шоколад no sugar added darknuts',
#  'печенье сдобное',
#  'мармелад жевательный клубника черника сливками',
#  'белый шоколад ручной работы апельсином',
#  'печенье',
#  'молочный шоколад ручной работы цельным фундуком',
#  'печенье сдобное',
#  'молочный шоколад ручной работы вишней',
#  'мармелад жевательный черника малина сливками',
#  'мармелад жевательный ассорти',
#  'печенье овсяное',
#  'крекер классический',
#  'мармелад жевательный соком ягод фруктов',
#  'мармелад жевательный витаминами',
#  'крекер сыром',
#  'крекер солью',
#  'крекер',
#  'шоколад горький bitter',
#  'детское печенье обогащенное кальцием',
#  'печенье сдобное кусочками глазури',
#  'печенье сдобное цветным драже',
#  'шоколад белый caramel',
#  'шоколад white and extra almond',
#  'конфеты цельным фундуком',
#  'драже хрустящий шарик малиновой глазури',
#  'драже арахис молочно-шоколадной цветной сахарной глазури',
#  'печенье протеиновое малиновый чизкейк',
#  'драже вафельный кубик молочно-шоколадной глазури',
#  'печенье протеиновое арахис соленой карамелью',
#  'драже',
#  'печенье choco boy йогурт клубника',
#  'шоколад milk extra hazelnut',
#  'шоколад горький dark extra almond',
#  'пастила фруктовая',
#  'карамель red berry',
#  'шоколад горький ecuador',
#  'карамель',
#  'карамель молочным вкусом',
#  'карамель вкусом клубники сливок',
#  'шоколад детский молочный',
#  'карамель',
#  'шоколад молочный арахисом',
#  'карамель начинкой фруктового вкуса',
#  'карамель фруктовое ассорти',
#  'шоколад молочный взрывной карамелью',
#  'шоколад белый',
#  'карамель вкусом мяты',
#  'шоколад молочный ананасом',
#  'печенье choco boy',
#  'драже фундук молочной глазури дробленой карамелью солью',
#  'шоколад молочный крекером',
#  'драже крекер молочно-шоколадной глазури',
#  'шоколад молочный',
#  'драже вафельный кубик молочно-шоколадной глазури',
#  'печенье безглютеновое клубника',
#  'печенье безглютеновое банан',
#  'детское печенье обогащённое йодом',
#  'драже арахис глазури',
#  'детское печенье обогащенное железом',
#  'печенье апельсиновыми цукатами',
#  'печенье овсяное изюмом',
#  'мармелад',
#  'карамель melody pops клубника',
#  'батончик',
#  'драже шоколад',
#  "батончик jet's",
#  'конфета шантарель вкусом айриш-крим',
#  'батончик',
#  'батончик',
#  'зерновой батончик клюквой',
#  'зерновой батончик кокосом',
#  'батончик арахиса клюквы',
#  'батончик крокант',
#  'драже соленый арахис',
#  'батончик спринт',
#  'галеты хрустящие',
#  'батончик',
#  'батончик',
#  'батончик вафельный воздушной кукурузой',
#  'драже арахисом',
#  'драже криспи',
#  'батончик вафельный',
#  'батончик вафельный мягкой карамели',
#  'батончик вафельный',
#  'конфеты вкусом черной смородины',
#  'конфеты шоколадным вкусом',
#  'батончик мюсли клюква-малина йогурте',
#  'батончик мюсли фруктовый',
#  'шоколад молочный фундуком',
#  'мармелад жевательный змейка',
#  'мармелад жевательный змейки кислой посыпке',
#  'крендельки бретцель солью',
#  'мармелад жевательный соком ягод фруктов',
#  'печенье choco boy сафари',
#  'конфеты',
#  'мармелад жевательный медвежата',
#  'конфеты',
#  'конфеты вкусом шоколада',
#  'конфеты арбуз',
#  'леденцы клубника-мята',
#  'леденцы лимон мята',
#  'драже жевательное фрукты',
#  'конфеты',
#  'конфеты',
#  'конфеты',
#  'конфеты',
#  'крекер классический',
#  'драже мята',
#  'конфеты',
#  'конфеты парное молочко',
#  'драже апельсин',
#  'конфеты',
#  'конфеты арахисом',
#  'конфеты семенами подсолнечника',
#  'конфеты',
#  'мармелад жевательный фансы',
#  'карамель ореховой начинкой',
#  'конфеты желейные',
#  'конфеты желейные фэнси',
#  'конфеты лимонным вкусом',
#  'конфеты сливочным вкусом',
#  'жевательные конфеты волшебный твист',
#  'конфета жевательная',
#  'жевательные конфеты вкусом колы фруктов',
#  'жевательные конфеты тропикс',
#  'карамель xxl trio',
#  'карамель экзотик тропик',
#  'батончик',
#  'батончик xtra печеньем',
#  'батончик шоколадный',
#  'батончик',
#  'шоколадный батончик супер',
#  'батончик',
#  'батончик',
#  'мармелад луана',
#  'шоколадные конфеты ореховая коллекция',
#  'донат ванильной начинкой',
#  'донат малиновой начинкой',
#  'донат шоколадной начинкой',
#  'фруктовая лента яблоко-малина',
#  'шоколад молочный начинками бисквитом брауни карамелью',
#  'шоколад молочный молочной начинкой',
#  'шоколад молочный молочной начинкой',
#  'конфеты имбирь бодрящий',
#  'вафля ореховой начинкой',
#  'пирожное',
#  'печенье chocostix лимонно-шоколадной глазури',
#  'трубочка вареным сгущенным молоком',
#  'трубочка вафельная вареным сгущенным молоком',
#  'зефир апельсином',
#  'печенье мультизлаковое яблочным соком',
#  'торт',
#  'шоколадный батончик white cookies',
#  'торт медовый',
#  'торт fun ban',
#  'шоколадный батончик white coconut cream',
#  'конфеты mini',
#  'шоколадный батончик white strawberry cream',
#  'пирожное колечки творогом',
#  'фруктовый батончик протеином',
#  'драже жевательные виноград',
#  'мармелад жевательный турбозавры',
#  'тонкий шоколад milk caramel',
#  'тонкий шоколад milk orange filling',
#  'шоколадный батончик',
#  'шоколадный батончик начинкой манго',
#  'карамель молочная',
#  'батончик super',
#  'печенье choco boy сафари кокос',
#  'печенье goute затяжное',
#  'крекер золотая рыбка',
#  'шоколад молочный ром',
#  'фунчоза',
#  'мюсли бананом шоколадом',
#  'макаронные изделия казаречче',
#  'готовый завтрак колечки медом',
#  'макароны campanelle',
#  'макаронные изделия спагетти',
#  'макаронные изделия перья',
#  'смесь выпечки блинчики',
#  'хлопья 4 злака',
#  'макаронные изделия вермишель',
#  'пшено отборное',
#  'макаронные изделия рожки',
#  'мука',
#  'макаронные изделия спирали',
#  'мука пшеничная цельнозерновая',
#  'макаронные изделия ракушка',
#  'мука пшеничная хлебопекарная высшего сорта',
#  'макаронные изделия фетучини',
#  'каша овсяная тигренок',
#  'макаронные изделия перья',
#  'мюсли арахисовая паста',
#  'мюсли клубника белый шоколад',
#  'макаронные изделия витки',
#  'крупа пшеничная янтарная пакетиках',
#  'макаронные изделия рожки',
#  'эко-хлопья гречневые',
#  'макаронные изделия спагетти',
#  'крупа гречневая',
#  'макаронные изделия спирали',
#  'крупа гречневая алтайская пакетиках',
#  'макаронные изделия лапша',
#  'крупа гречневая органическая органическая алтайская',
#  'макаронные изделия рожки',
#  'рис круглозерный кубанский пакетиках',
#  'макаронные изделия спагетти',
#  'чечевица красная',
#  'макаронные изделия спирали',
#  'греча овощами',
#  'макаронные изделия витки',
#  'рис басмати пропаренный',
#  'макаронные изделия фетучини',
#  'гречка',
#  'рис круглозерный',
#  'макароны спагетти',
#  'перловая крупа',
#  'макароны вермишель',
#  'мюсли granola crunchy ореховая',
#  'горох колотый',
#  'макароны витки',
#  'крупа кукурузная',
#  'макароны рожки',
#  'мука кукурузная',
#  'крупа манная',
#  'макароны спирали',
#  'крупа пшеничная',
#  'макароны перья',
#  'крупа ячневая',
#  'пшено',
#  'рис длиннозерный',
#  'рис длиннозерный пропаренный',
#  'хлопья овсяные',
#  'лапша гнёзда итальянские',
#  'крупа гречневая',
#  'лапша',
#  'рис круглозерный',
#  'смесь выпечки кекс малиновый',
#  ...]
